# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
## read images

nobita = cv2.imread("Nobita.jpg")

shizuka = cv2.imread("Shizuka.jpg")

# %%
# orignal image
plt.imshow(nobita)

# %%
# orignal dimensions
plt.imshow(shizuka)

# %%
#face dimensions
nobita = nobita[:230,:]
plt.imshow(nobita)

# %%
## Face dimensions
shizuka = shizuka[9:239,:]
plt.imshow(shizuka)

# %%
shizuka[9:239,45:445] = nobita[0:230,:400]

# %%
## show image with swaped faces 

cv2.imshow("Mix_Photo",shizuka)
cv2.waitKey()
cv2.destroyAllWindows()
